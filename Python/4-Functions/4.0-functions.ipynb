# %% [markdown]
# # Functions
#
# 1. Introduction to Functions
# 2. Defining Functions
# 3. Calling a Function
# 4. Types of Function Arguments
# 5. Return Statement

# %% [markdown]
# 1. Introduction to Functions
#
#     A function is a block of code that performs a specific task. Functions help in organizing code, reusing code, and improving readability.

# %%
# Syntax

def function_name(parameters):
    """Docstring"""
    # Function body
    return expression

# %% [markdown]
# Why functions?

# %%
num = 24
if num % 2 == 0:
    print("The number is even")
else:
    print("The number is odd")
# Out:
# The number is even

# %%
def even_or_odd(num):
    """This function finds even or odd"""
    if num % 2 == 0:
        print("The number is even")
    else:
        print("The number is odd")

# %% [markdown]
# 3. Calling a Function

# %%
# Call this function
even_or_odd(24)
# Out:
# The number is even

# %% [markdown]
# 4. Types of Function Arguments
#
#     Python supports various types of arguments that can be passed at the time of the function call. Below are types of function argument types:.

# %%
def add(a, b):
    return a + b

result = add(2, 4)
print(result)
# Out:
# 6

# %% [markdown]
# - Default Arguments: A default argument is a parameter that assumes a default value if a value is not provided in the function call for that argument.

# %%
def greet(name):
    print(f"Hello {name} Welcome to the paradise")

greet("Ankit")
# Out:
# Hello Ankit Welcome to the paradise

# %%
def greet(name = "Guest"):
    print(f"Hello {name} Welcome to the paradise")

greet()
# Out:
# Hello Guest Welcome to the paradise

# %%
def greet(name = "Guest"):
    print(f"Hello {name} Welcome to the paradise")

greet("Ankit")
# Out:
# Hello Ankit Welcome to the paradise

# %% [markdown]
# - Arbitrary Arguments: allow a function to accept a variable number of inputs. This is done using two special symbols:
#     - *args: collects extra positional (non-keyword) arguments as a tuple.
#     - **kwargs: collects extra keyword arguments as a dictionary.

# %%
# *args

def print_numbers(*Ankit):
    for number in Ankit:
        print(number)

# %%
print_numbers(1,2,3,4,5,6,7,"Ankit")
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# Ankit

# %%
def print_numbers(*args):
    for number in args:
        print(number)

# %%
print_numbers(1,2,3,4,5,6,7,"Ankit")
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# Ankit

# %%
# Keywords Arguments
def print_details(**kwargs):
    for key, value in kwargs.items():
        print(f"{key}: {value}")

# %%
print_details(name = "Ankit", age = "19", country = "India")
# Out:
# name: Ankit
# age: 19
# country: India

# %% [markdown]
# - Keyword Arguments: values are passed by explicitly specifying the parameter names, so the order doesn’t matter.

# %%
def my_function(animal, name):
  print("I have a", animal)
  print("My", animal + "'s name is", name)

my_function(animal = "dog", name = "Buddy")
# Out:
# I have a dog
# My dog's name is Buddy

# %% [markdown]
# - Positional Arguments: When you call a function with arguments without using keywords, they are called positional arguments.

# %%
def my_function(animal, name):
  print("I have a", animal)
  print("My", animal + "'s name is", name)

my_function("dog", "Buddy")
# Out:
# I have a dog
# My dog's name is Buddy

# %%
# Using both

def print_details(*args, **kwargs):
    for val in args:
        print(f"Positional args: {val}")

    for key, value in kwargs.items():
        print(f"{key}: {value}")

# %%
print_details(1,2,3,4,"Ankit", name = "Ankit", age = "19", country = "India")
# Out:
# Positional args: 1
# Positional args: 2
# Positional args: 3
# Positional args: 4
# Positional args: Ankit
# name: Ankit
# age: 19
# country: India

# %%
# Return statements

def multiply(a, b):
    return a*b

multiply(2,6)
# Out:
# 12

# %%
# Return Multiple Parameter

def multiply(a, b):
    return a*b,a

multiply(2,6)
# Out:
# (12, 2)
